# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    #tick_marks = np.arange(len(iris.target_names))
    #plt.xticks(tick_marks, iris.target_names, rotation=45)
    #plt.yticks(tick_marks, iris.target_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')


# Compute confusion matrix
#cm = confusion_matrix(y_test, y_pred)
cm = np.load('../data/external/InceptionV3_UpmcFood101_confm.npy')
np.set_printoptions(precision=2)
print('Confusion matrix, without normalization')
print(cm)
plt.figure()
plot_confusion_matrix(cm)
plt.show()
# Out:
# Confusion matrix, without normalization
# [[150   0   5 ...,   0   0   3]
#  [  0 153   1 ...,   0   0   0]
#  [  7   1 181 ...,   0   0   0]
#  ...,
#  [  1   0   1 ..., 170   0   0]
#  [  1   1   0 ...,   0 117   1]
#  [  2   0   1 ...,   0   0 180]]

# %%
# Normalize the confusion matrix by row (i.e by the number of samples
# in each class)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Normalized confusion matrix')
print(cm_normalized)
plt.figure()
plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')

plt.show()
# Out:
# Normalized confusion matrix
# [[ 0.64  0.    0.02 ...,  0.    0.    0.01]
#  [ 0.    0.69  0.   ...,  0.    0.    0.  ]
#  [ 0.03  0.    0.8  ...,  0.    0.    0.  ]
#  ...,
#  [ 0.    0.    0.   ...,  0.73  0.    0.  ]
#  [ 0.    0.    0.   ...,  0.    0.55  0.  ]
#  [ 0.01  0.    0.   ...,  0.    0.    0.77]]

# %%
classes = ["apple_pie",
"baby_back_ribs",
"baklava",
"beef_carpaccio",
"beef_tartare",
"beet_salad",
"beignets",
"bibimbap",
"bread_pudding",
"breakfast_burrito",
"bruschetta",
"caesar_salad",
"cannoli",
"caprese_salad",
"carrot_cake",
"ceviche",
"cheesecake",
"cheese_plate",
"chicken_curry",
"chicken_quesadilla",
"chicken_wings",
"chocolate_cake",
"chocolate_mousse",
"churros",
"clam_chowder",
"club_sandwich",
"crab_cakes",
"creme_brulee",
"croque_madame",
"cup_cakes",
"deviled_eggs",
"donuts",
"dumplings",
"edamame",
"eggs_benedict",
"escargots",
"falafel",
"filet_mignon",
"fish_and_chips",
"foie_gras",
"french_fries",
"french_onion_soup",
"french_toast",
"fried_calamari",
"fried_rice",
"frozen_yogurt",
"garlic_bread",
"gnocchi",
"greek_salad",
"grilled_cheese_sandwich",
"grilled_salmon",
"guacamole",
"gyoza",
"hamburger",
"hot_and_sour_soup",
"hot_dog",
"huevos_rancheros",
"hummus",
"ice_cream",
"lasagna",
"lobster_bisque",
"lobster_roll_sandwich",
"macaroni_and_cheese",
"macarons",
"miso_soup",
"mussels",
"nachos",
"omelette",
"onion_rings",
"oysters",
"pad_thai",
"paella",
"pancakes",
"panna_cotta",
"peking_duck",
"pho",
"pizza",
"pork_chop",
"poutine",
"prime_rib",
"pulled_pork_sandwich",
"ramen",
"ravioli",
"red_velvet_cake",
"risotto",
"samosa",
"sashimi",
"scallops",
"seaweed_salad",
"shrimp_and_grits",
"spaghetti_bolognese",
"spaghetti_carbonara",
"spring_rolls",
"steak",
"strawberry_shortcake",
"sushi",
"tacos",
"takoyaki",
"tiramisu",
"tuna_tartare",
"waffles"]

# %%
print(classes[58])
print(classes[45])
print("Pred ice_cream & True label ice_cream : "
      + str(cm[58][58]))
print("Pred frozen_yogurt & True label ice_cream : "
      + str(cm[45][58]))
# Out:
# ice_cream
# frozen_yogurt
# Pred ice_cream & True label ice_cream : 102
# Pred frozen_yogurt & True label ice_cream : 17

# %%
print(classes[55])
print(classes[61])
print("Pred hot_dog & True label hot_dog : "
      + str(cm[55][55]))
print("Pred lobster_roll_sandwich & True hot_dog : "
      + str(cm[61][55]))
# Out:
# hot_dog
# lobster_roll_sandwich
# Pred hot_dog & True label hot_dog : 40
# Pred lobster_roll_sandwich & True hot_dog : 12

# %%
print('Number of sample in each classes')
print(cm.sum(axis=1))
# Out:
# Number of sample in each classes
# [234 221 226 222 225 224 224 225 226 214 231 227 230 220 231 227 233 224
#  222 220 219 232 224 230 224 220 221 225 224 228 229 232 228 231 213 202
#  228 212 208 216 212 223 238 212 229 233 224 234 223 229 225 228 232 233
#  203 234 223 234 232 233 197 215 238 231 227 234 224 231 217 223 230 228
#  234 225 211 218 235 227 210 220 224 232 236 227 236 215 226 228 219 228
#  213 218 230 229 223 237 233 223 232 211 235]

# %%
print('Number of sample predicted for each classes')
print(cm.sum(axis=0))
# Out:
# Number of sample predicted for each classes
# [288 231 234 221 186 202 245 227 231 248 252 246 267 248 209 221 212 183
#  250 207 245 230 246 219 240 206 232 242 195 192 249 225 222 272 202 185
#  219 197 181 196 233 261 205 185 251 285 242 216 215 224 228 243 221 238
#  157 173 184 248 228 229 184 240 237 233 259 226 205 240 197 242 235 231
#  298 230 188 213 256 229 215 215 237 190 237 243 248 196 180 217 198 235
#  246 230 202 241 249 228 232 222 229 198 216]

# %%
error = cm.sum(axis=0) * 1. / cm.sum(axis=1) - 1
argsort = np.argsort(error * np.sign(error))
print('Id of classes ranked by decroissante error')
print(argsort)
# Out:
# Id of classes ranked by decroissante error
# [ 62  82  96  97   3  21  63  77   7  98  71  50  59  58  53  70  49   8
#   73  79  75  78  32  15  31  89  65   2  48  95  67  36   1  52  23  87
#   26  84  34  93  91  80  19  57  99  25  51  60  83  37  24  27  47  46
#  100  11  35  66  69  30  85  76  16  10  68  39   6  14  88  44   5  22
#   40  74  61  94  20  92  18  13  43  28  38  42  64  90  29   9  12  41
#    4  56  33  81  17  86  45  54   0  55  72]

# %%
print('Five most easiest classes:')
print(classes[62])
print(classes[82])
print(classes[96])
print(classes[97])
print(classes[3])
# Out:
# Five most easiest classes:
# macaroni_and_cheese
# ravioli
# tacos
# takoyaki
# beef_carpaccio

# %%
print('Five most difficult classes:')
print(classes[72])
print(classes[55])
print(classes[0])
print(classes[54])
print(classes[45])
# Out:
# Five most difficult classes:
# pancakes
# hot_dog
# apple_pie
# hot_and_sour_soup
# frozen_yogurt
